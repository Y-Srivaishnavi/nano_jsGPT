# %% [markdown]
# <a href="https://colab.research.google.com/github/Y-Srivaishnavi/nano_jsGPT/blob/main/data_extraction/js_docs_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin, urlparse
from collections import deque

# Initialize a queue with the starting URL
url_queue = deque([' https://developer.mozilla.org/en-US/docs/Web/JavaScript'])

# Set to store visited URLs to avoid revisiting pages
visited_urls = set()

# Maximum number of pages to scrape
max_pages = 2000

# Function to scrape a single page
def scrape_page(url):
    try:
        response = requests.get(url)
        response.raise_for_status()
        soup = BeautifulSoup(response.text, 'html.parser')

        # Targeting only the specified article for textual content
        article_content = soup.find('article', class_='main-page-content', lang='en-US')
        if article_content:
            paragraphs = [p.text.strip() for p in article_content.find_all('p')]
        else:
            paragraphs = []

        # Extract links from the entire page, not just the article, to continue the crawl
        links = [a.get('href') for a in soup.find_all('a', href=True)]
        for link in links:
            absolute_link = urljoin(url, link)
            if urlparse(absolute_link).netloc == urlparse(url).netloc and absolute_link not in visited_urls:
                url_queue.append(absolute_link)

        return {
            'url': url,
            'paragraphs': paragraphs
        }

    except requests.RequestException as e:
        print(f"Request failed: {e}")
        return None


# Main loop to process URLs in the queue
scraped_data = []
pages_scraped = 0  # Counter for pages scraped

while url_queue and pages_scraped < max_pages:
    current_url = url_queue.popleft()
    if current_url not in visited_urls:
        print(f"Scraping {current_url}...")
        data = scrape_page(current_url)
        if data:
            scraped_data.append(data)
            pages_scraped += 1  # Increment the counter after a successful scrape
        # Mark the current URL as visited
        visited_urls.add(current_url)
# Out:
# Scraping  https://developer.mozilla.org/en-US/docs/Web/JavaScript...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript#content...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript#top-nav-search-input...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript#languages-switcher-button...
# Scraping https://developer.mozilla.org/en-US/...
# Scraping https://developer.mozilla.org/en-US/docs/Web...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTML...
# Scraping https://developer.mozilla.org/en-US/docs/Web/CSS...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTTP...
# Scraping https://developer.mozilla.org/en-US/docs/Web/API...
# Scraping https://developer.mozilla.org/en-US/docs/Mozilla/Add-ons/WebExtensions...
# Scraping https://developer.mozilla.org/en-US/docs/Learn...
# Scraping https://developer.mozilla.org/en-US/docs/Learn/HTML...
# Scraping https://developer.mozilla.org/en-US/docs/Learn/CSS...
# Scraping https://developer.mozilla.org/en-US/docs/Learn/JavaScript...
# Scraping https://developer.mozilla.org/en-US/docs/Web/Accessibility...
# Scraping https://developer.mozilla.org/en-US/plus...
# Scraping https://developer.mozilla.org/en-US/plus/ai-help...
# Scraping https://developer.mozilla.org/en-US/plus/updates...
# Scraping https://developer.mozilla.org/en-US/plus/docs/features/overview...
# Scraping https://developer.mozilla.org/en-US/plus/docs/faq...
# Scraping https://developer.mozilla.org/en-US/blog/...
# Scraping https://developer.mozilla.org/en-US/play...
# Scraping https://developer.mozilla.org/users/fxa/login/authenticate/?next=%2Fen-US%2Fdocs%2FWeb%2FJavaScript...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript#tutorials...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript#reference...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Tutorials...
# Scraping https://developer.mozilla.org/en-US/docs/Learn/Getting_started_with_the_web/JavaScript_basics...
# Scraping https://developer.mozilla.org/en-US/docs/Learn/JavaScript/First_steps...
# Scraping https://developer.mozilla.org/en-US/docs/Learn/JavaScript/Building_blocks...
# Scraping https://developer.mozilla.org/en-US/docs/Learn/JavaScript/Objects...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Guide/Introduction...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Guide/Grammar_and_types...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Guide/Control_flow_and_error_handling...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Guide/Loops_and_iteration...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Guide/Functions...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Guide/Expressions_and_operators...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Guide/Numbers_and_dates...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Guide/Text_formatting...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Guide/Regular_expressions...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Guide/Indexed_collections...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Guide/Keyed_collections...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Guide/Working_with_objects...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Guide/Using_classes...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Guide/Using_promises...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Guide/Typed_arrays...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Guide/Iterators_and_generators...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Guide/Meta_programming...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Guide/Modules...
# Scraping https://developer.mozilla.org/en-US/docs/Learn/Tools_and_testing/Client-side_JavaScript_frameworks...
# Scraping https://developer.mozilla.org/en-US/docs/Learn/JavaScript/Client-side_web_APIs...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Language_overview...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Data_structures...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Equality_comparisons_and_sameness...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Enumerability_and_ownership_of_properties...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Closures...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Inheritance_and_the_prototype_chain...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Memory_management...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Event_loop...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Global_Objects...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Global_Objects/AggregateError...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Global_Objects/Array...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Global_Objects/ArrayBuffer...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Global_Objects/AsyncFunction...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Global_Objects/AsyncGenerator...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Global_Objects/AsyncGeneratorFunction...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Global_Objects/AsyncIterator...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Global_Objects/Atomics...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Global_Objects/BigInt...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Global_Objects/BigInt64Array...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Global_Objects/BigUint64Array...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Global_Objects/Boolean...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Global_Objects/DataView...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Global_Objects/Date...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Global_Objects/decodeURI...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Global_Objects/decodeURIComponent...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Global_Objects/encodeURI...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Global_Objects/encodeURIComponent...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Global_Objects/Error...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Global_Objects/escape...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Global_Objects/eval...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Global_Objects/EvalError...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Global_Objects/FinalizationRegistry...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Global_Objects/Float32Array...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Global_Objects/Float64Array...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Global_Objects/Function...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Global_Objects/Generator...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Global_Objects/GeneratorFunction...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Global_Objects/globalThis...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Global_Objects/Infinity...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Global_Objects/Int16Array...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Global_Objects/Int32Array...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Global_Objects/Int8Array...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Global_Objects/InternalError...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Global_Objects/Intl...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Global_Objects/isFinite...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Global_Objects/isNaN...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Global_Objects/Iterator...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Global_Objects/JSON...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Global_Objects/Map...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Global_Objects/Math...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Global_Objects/NaN...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Global_Objects/Number...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Global_Objects/Object...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Global_Objects/parseFloat...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Global_Objects/parseInt...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Global_Objects/Promise...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Global_Objects/Proxy...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Global_Objects/RangeError...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Global_Objects/ReferenceError...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Global_Objects/Reflect...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Global_Objects/RegExp...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Global_Objects/Set...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Global_Objects/SharedArrayBuffer...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Global_Objects/String...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Global_Objects/Symbol...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Global_Objects/SyntaxError...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Global_Objects/TypedArray...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Global_Objects/TypeError...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Global_Objects/Uint16Array...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Global_Objects/Uint32Array...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Global_Objects/Uint8Array...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Global_Objects/Uint8ClampedArray...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Global_Objects/undefined...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Global_Objects/unescape...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Global_Objects/URIError...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Global_Objects/WeakMap...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Global_Objects/WeakRef...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Global_Objects/WeakSet...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Operators...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Operators/Addition...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Operators/Addition_assignment...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Operators/Assignment...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Operators/async_function...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Operators/async_function*...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Operators/await...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Operators/Bitwise_AND...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Operators/Bitwise_AND_assignment...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Operators/Bitwise_NOT...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Operators/Bitwise_OR...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Operators/Bitwise_OR_assignment...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Operators/Bitwise_XOR...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Operators/Bitwise_XOR_assignment...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Operators/class...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Operators/Comma_operator...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Operators/Conditional_operator...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Operators/Decrement...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Operators/delete...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Operators/Destructuring_assignment...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Operators/Division...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Operators/Division_assignment...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Operators/Equality...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Operators/Exponentiation...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Operators/Exponentiation_assignment...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Operators/function...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Operators/function*...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Operators/Greater_than...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Operators/Greater_than_or_equal...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Operators/Grouping...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Operators/import.meta...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Operators/import...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Operators/in...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Operators/Increment...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Operators/Inequality...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Operators/instanceof...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Operators/Left_shift...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Operators/Left_shift_assignment...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Operators/Less_than...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Operators/Less_than_or_equal...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Operators/Logical_AND...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Operators/Logical_AND_assignment...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Operators/Logical_NOT...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Operators/Logical_OR...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Operators/Logical_OR_assignment...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Operators/Multiplication...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Operators/Multiplication_assignment...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Operators/new...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Operators/new.target...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Operators/null...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Operators/Nullish_coalescing_assignment...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Operators/Nullish_coalescing...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Operators/Object_initializer...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Operators/Operator_precedence...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Operators/Optional_chaining...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Operators/Property_accessors...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Operators/Remainder...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Operators/Remainder_assignment...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Operators/Right_shift...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Operators/Right_shift_assignment...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Operators/Spread_syntax...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Operators/Strict_equality...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Operators/Strict_inequality...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Operators/Subtraction...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Operators/Subtraction_assignment...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Operators/super...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Operators/this...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Operators/typeof...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Operators/Unary_negation...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Operators/Unary_plus...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Operators/Unsigned_right_shift...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Operators/Unsigned_right_shift_assignment...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Operators/void...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Operators/yield...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Operators/yield*...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Statements...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Statements/async_function...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Statements/async_function*...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Statements/block...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Statements/break...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Statements/class...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Statements/const...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Statements/continue...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Statements/debugger...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Statements/do...while...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Statements/Empty...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Statements/export...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Statements/Expression_statement...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Statements/for...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Statements/for-await...of...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Statements/for...in...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Statements/for...of...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Statements/function...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Statements/function*...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Statements/if...else...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Statements/import...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Statements/label...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Statements/let...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Statements/return...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Statements/switch...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Statements/throw...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Statements/try...catch...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Statements/var...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Statements/while...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Statements/with...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Functions...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Functions/Arrow_functions...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Functions/Default_parameters...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Functions/get...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Functions/Method_definitions...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Functions/rest_parameters...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Functions/set...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Functions/arguments...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Classes...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Classes/constructor...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Classes/extends...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Classes/Private_properties...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Classes/Public_class_fields...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Classes/static...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Classes/Static_initialization_blocks...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Regular_expressions...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Regular_expressions/Backreference...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Regular_expressions/Capturing_group...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Regular_expressions/Character_class_escape...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Regular_expressions/Character_class...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Regular_expressions/Character_escape...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Regular_expressions/Disjunction...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Regular_expressions/Input_boundary_assertion...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Regular_expressions/Literal_character...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Regular_expressions/Lookahead_assertion...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Regular_expressions/Lookbehind_assertion...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Regular_expressions/Named_backreference...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Regular_expressions/Named_capturing_group...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Regular_expressions/Non-capturing_group...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Regular_expressions/Quantifier...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Regular_expressions/Unicode_character_class_escape...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Regular_expressions/Wildcard...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Regular_expressions/Word_boundary_assertion...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Errors...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Errors/Property_access_denied...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Errors/Too_much_recursion...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Errors/Not_a_valid_code_point...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Errors/BigInt_division_by_zero...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Errors/BigInt_negative_exponent...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Errors/Invalid_array_length...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Errors/Invalid_date...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Errors/Precision_range...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Errors/Bad_radix...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Errors/Resulting_string_too_large...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Errors/Negative_repetition_count...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Errors/Cant_be_converted_to_BigInt_because_it_isnt_an_integer...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Errors/Not_defined...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Errors/Undeclared_var...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Errors/Cant_access_lexical_declaration_before_init...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Errors/Deprecated_caller_or_arguments_usage...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Errors/Undefined_prop...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Errors/Deprecated_octal...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Errors/Strict_non_simple_params...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Errors/Reserved_identifier...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Errors/Invalid_for-of_initializer...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Errors/Delete_in_strict_mode...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Errors/Bad_await...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Errors/Cant_use_nullish_coalescing_unparenthesized...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Errors/Bad_continue...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Errors/Invalid_for-in_initializer...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Errors/Unnamed_function_statement...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Errors/Either_be_both_static_or_non-static...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Errors/Identifier_after_number...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Errors/Illegal_character...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Errors/Invalid_assignment_left-hand_side...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Errors/Invalid_BigInt_syntax...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Errors/Bad_regexp_flag...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Errors/JSON_bad_parse...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Errors/Label_not_found...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Errors/Missing_semicolon_before_statement...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Errors/Missing_colon_after_property_id...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Errors/Missing_parenthesis_after_argument_list...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Errors/Missing_parenthesis_after_condition...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Errors/Missing_bracket_after_list...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Errors/Missing_curly_after_function_body...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Errors/Missing_curly_after_property_list...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Errors/Missing_initializer_in_const...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Errors/Missing_formal_parameter...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Errors/Missing_name_after_dot_operator...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Errors/No_variable_name...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Errors/Redeclared_parameter...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Errors/Bad_return...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Errors/Equal_as_assign...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Errors/Hash_outside_class...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Errors/Unexpected_token...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Errors/Bad_break...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Errors/Unparenthesized_unary_expr_lhs_exponentiation...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Errors/Unterminated_string_literal...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Errors/Deprecated_source_map_pragma...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Errors/is_not_iterable...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Errors/No_properties...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Errors/Unexpected_type...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Errors/Not_a_constructor...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Errors/Not_a_function...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Errors/No_non-null_object...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Errors/Read-only...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Errors/Cant_assign_to_property...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Errors/Cant_convert_BigInt_to_number...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Errors/Cant_convert_x_to_BigInt...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Errors/Cant_define_property_object_not_extensible...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Errors/Non_configurable_array_element...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Errors/Cant_redefine_property...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Errors/in_operator_no_object...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Errors/Cyclic_object_value...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Errors/invalid_right_hand_side_instanceof_operand...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Errors/Array_sort_argument...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Errors/Invalid_const_assignment...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Errors/More_arguments_needed...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Errors/Cant_delete...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Errors/Reduce_of_empty_array_with_no_initial_value...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Errors/Getter_only...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Errors/Called_on_incompatible_type...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Errors/Malformed_URI...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Errors/Already_has_pragma...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Errors/Stmt_after_return...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/JavaScript_technologies_overview...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Lexical_grammar...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Iteration_protocols...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Strict_mode...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Template_literals...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Trailing_commas...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Deprecated_and_obsolete_features...
# Scraping https://developer.mozilla.org/en-US/docs/Glossary/First-class_Function...
# Scraping https://developer.mozilla.org/en-US/docs/Glossary/Node.js...
# Scraping https://developer.mozilla.org/en-US/docs/Glossary/Prototype-based_programming...
# Scraping https://developer.mozilla.org/en-US/docs/Glossary/Thread...
# Scraping https://developer.mozilla.org/en-US/docs/Glossary/Dynamic_typing...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Global_Objects/Object#static_methods...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Global_Objects/Function/toString...
# Scraping https://developer.mozilla.org/en-US/docs/Glossary/API...
# Scraping https://developer.mozilla.org/en-US/docs/Glossary/DOM...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Guide...
# Scraping https://developer.mozilla.org/en-US/docs/Learn/Front-end_web_developer...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript#for_complete_beginners...
# Scraping https://developer.mozilla.org/en-US/docs/Learn/JavaScript/Asynchronous...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript#javascript_guide...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript#intermediate...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Global_Objects/Object/is...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript#advanced...
# Scraping https://developer.mozilla.org/en-US/docs/Web/JavaScript/contributors.txt...
# Scraping https://developer.mozilla.org/...
# Scraping https://developer.mozilla.org/en-US/blog/rss.xml...
# Scraping https://developer.mozilla.org/en-US/about...
# /usr/lib/python3.10/html/parser.py:170: XMLParsedAsHTMLWarning: It looks like you're parsing an XML document using an HTML parser. If this really is an HTML document (maybe it's XHTML?), you can ignore or filter this warning. If it's XML, you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the lxml package installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#   k = self.parse_starttag(i)
# Scraping https://developer.mozilla.org/en-US/advertising...
# Scraping https://developer.mozilla.org/en-US/docs/MDN/Community/Issues...
# Scraping https://developer.mozilla.org/en-US/community...
# Scraping https://developer.mozilla.org/discord...
# Scraping https://developer.mozilla.org/en-US/docs/MDN/Writing_guidelines/Attrib_copyright_license...
# Scraping https://developer.mozilla.org/en-US/#content...
# Scraping https://developer.mozilla.org/en-US/#top-nav-search-input...
# Scraping https://developer.mozilla.org/users/fxa/login/authenticate/?next=%2Fen-US%2F...
# Scraping https://developer.mozilla.org/en-US/blog/regular-expressions-reference-updates/...
# Scraping https://developer.mozilla.org/en-US/blog/aria-accessibility-html-landmark-roles/...
# Scraping https://developer.mozilla.org/en-US/docs/Web/API/Performance_API...
# Scraping https://developer.mozilla.org/en-US/docs/Web/CSS/CSS_nesting...
# Scraping https://developer.mozilla.org/en-US/blog/introducing-ai-help/...
# Scraping https://developer.mozilla.org/en-US/blog/introducing-the-mdn-playground/...
# Scraping https://developer.mozilla.org/en-US/community/spotlight/yuji...
# Scraping https://developer.mozilla.org/en-US/docs/Web#content...
# Scraping https://developer.mozilla.org/en-US/docs/Web#top-nav-search-input...
# Scraping https://developer.mozilla.org/en-US/docs/Web#languages-switcher-button...
# Scraping https://developer.mozilla.org/users/fxa/login/authenticate/?next=%2Fen-US%2Fdocs%2FWeb...
# Scraping https://developer.mozilla.org/en-US/docs/Web#documentation_for_web_developers...
# Scraping https://developer.mozilla.org/en-US/docs/Web#web_technology_references...
# Scraping https://developer.mozilla.org/en-US/docs/Web#developer_tools_documentation...
# Scraping https://developer.mozilla.org/en-US/docs/Web/Demos...
# Scraping https://developer.mozilla.org/en-US/docs/Web/Guide...
# Scraping https://developer.mozilla.org/en-US/docs/Web/EXSLT...
# Scraping https://developer.mozilla.org/en-US/docs/Web/Events...
# Scraping https://developer.mozilla.org/en-US/docs/Web/MathML...
# Scraping https://developer.mozilla.org/en-US/docs/Web/OpenSearch...
# Scraping https://developer.mozilla.org/en-US/docs/Web/Privacy...
# Scraping https://developer.mozilla.org/en-US/docs/Web/Progressive_web_apps...
# Scraping https://developer.mozilla.org/en-US/docs/Web/SVG...
# Scraping https://developer.mozilla.org/en-US/docs/Web/Security...
# Scraping https://developer.mozilla.org/en-US/docs/Web/Text_fragments...
# Scraping https://developer.mozilla.org/en-US/docs/Web/Tutorials...
# Scraping https://developer.mozilla.org/en-US/docs/Web/Manifest...
# Scraping https://developer.mozilla.org/en-US/docs/Web/Media...
# Scraping https://developer.mozilla.org/en-US/docs/Web/Performance...
# Scraping https://developer.mozilla.org/en-US/docs/Web/WebDriver...
# Scraping https://developer.mozilla.org/en-US/docs/Web/XML...
# Scraping https://developer.mozilla.org/en-US/docs/Web/XPath...
# Scraping https://developer.mozilla.org/en-US/docs/Web/XSLT...
# Scraping https://developer.mozilla.org/en-US/docs/WebAssembly...
# Scraping https://developer.mozilla.org/en-US/docs/Web/API/Web_components...
# Scraping https://developer.mozilla.org/en-US/docs/Web/contributors.txt...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTML#content...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTML#top-nav-search-input...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTML#languages-switcher-button...
# Scraping https://developer.mozilla.org/users/fxa/login/authenticate/?next=%2Fen-US%2Fdocs%2FWeb%2FHTML...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTML#key_resources...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTML#beginners_tutorials...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTML#advanced_topics...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTML#reference...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTML#related_topics...
# Scraping https://developer.mozilla.org/en-US/docs/Learn/Getting_started_with_the_web/HTML_basics...
# Scraping https://developer.mozilla.org/en-US/docs/Learn/HTML/Introduction_to_HTML...
# Scraping https://developer.mozilla.org/en-US/docs/Learn/HTML/Introduction_to_HTML/Getting_started...
# Scraping https://developer.mozilla.org/en-US/docs/Learn/HTML/Introduction_to_HTML/The_head_metadata_in_HTML...
# Scraping https://developer.mozilla.org/en-US/docs/Learn/HTML/Introduction_to_HTML/HTML_text_fundamentals...
# Scraping https://developer.mozilla.org/en-US/docs/Learn/HTML/Introduction_to_HTML/Creating_hyperlinks...
# Scraping https://developer.mozilla.org/en-US/docs/Learn/HTML/Introduction_to_HTML/Advanced_text_formatting...
# Scraping https://developer.mozilla.org/en-US/docs/Learn/HTML/Introduction_to_HTML/Document_and_website_structure...
# Scraping https://developer.mozilla.org/en-US/docs/Learn/HTML/Introduction_to_HTML/Debugging_HTML...
# Scraping https://developer.mozilla.org/en-US/docs/Learn/HTML/Introduction_to_HTML/Marking_up_a_letter...
# Scraping https://developer.mozilla.org/en-US/docs/Learn/HTML/Introduction_to_HTML/Structuring_a_page_of_content...
# Scraping https://developer.mozilla.org/en-US/docs/Learn/HTML/Multimedia_and_embedding...
# Scraping https://developer.mozilla.org/en-US/docs/Learn/HTML/Multimedia_and_embedding/Images_in_HTML...
# Scraping https://developer.mozilla.org/en-US/docs/Learn/HTML/Multimedia_and_embedding/Video_and_audio_content...
# Scraping https://developer.mozilla.org/en-US/docs/Learn/HTML/Multimedia_and_embedding/Other_embedding_technologies...
# Scraping https://developer.mozilla.org/en-US/docs/Learn/HTML/Multimedia_and_embedding/Adding_vector_graphics_to_the_Web...
# Scraping https://developer.mozilla.org/en-US/docs/Learn/HTML/Multimedia_and_embedding/Responsive_images...
# Scraping https://developer.mozilla.org/en-US/docs/Learn/HTML/Multimedia_and_embedding/Mozilla_splash_page...
# Scraping https://developer.mozilla.org/en-US/docs/Learn/HTML/Tables...
# Scraping https://developer.mozilla.org/en-US/docs/Learn/HTML/Tables/Basics...
# Scraping https://developer.mozilla.org/en-US/docs/Learn/HTML/Tables/Advanced...
# Scraping https://developer.mozilla.org/en-US/docs/Learn/HTML/Tables/Structuring_planet_data...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTML/Reference...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTML/Element/a...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTML/Element/abbr...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTML/Element/acronym...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTML/Element/address...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTML/Element/area...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTML/Element/article...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTML/Element/aside...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTML/Element/audio...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTML/Element/b...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTML/Element/base...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTML/Element/bdi...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTML/Element/bdo...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTML/Element/big...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTML/Element/blockquote...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTML/Element/body...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTML/Element/br...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTML/Element/button...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTML/Element/canvas...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTML/Element/caption...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTML/Element/center...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTML/Element/cite...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTML/Element/code...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTML/Element/col...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTML/Element/colgroup...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTML/Element/data...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTML/Element/datalist...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTML/Element/dd...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTML/Element/del...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTML/Element/details...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTML/Element/dfn...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTML/Element/dialog...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTML/Element/dir...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTML/Element/div...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTML/Element/dl...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTML/Element/dt...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTML/Element/em...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTML/Element/embed...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTML/Element/fieldset...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTML/Element/figcaption...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTML/Element/figure...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTML/Element/font...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTML/Element/footer...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTML/Element/form...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTML/Element/frame...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTML/Element/frameset...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTML/Element/Heading_Elements...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTML/Element/head...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTML/Element/header...
# ...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/425...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/426...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/428...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/429...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/431...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/451...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/500...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/501...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/502...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/503...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/504...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/505...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/506...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/507...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/508...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/510...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/511...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTTP/Headers/Content-Security-Policy/Sources...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTTP/Headers/Content-Security-Policy/base-uri...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTTP/Headers/Content-Security-Policy/block-all-mixed-content...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTTP/Headers/Content-Security-Policy/child-src...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTTP/Headers/Content-Security-Policy/connect-src...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTTP/Headers/Content-Security-Policy/default-src...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTTP/Headers/Content-Security-Policy/font-src...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTTP/Headers/Content-Security-Policy/form-action...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTTP/Headers/Content-Security-Policy/frame-ancestors...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTTP/Headers/Content-Security-Policy/frame-src...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTTP/Headers/Content-Security-Policy/img-src...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTTP/Headers/Content-Security-Policy/manifest-src...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTTP/Headers/Content-Security-Policy/media-src...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTTP/Headers/Content-Security-Policy/object-src...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTTP/Headers/Content-Security-Policy/plugin-types...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTTP/Headers/Content-Security-Policy/prefetch-src...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTTP/Headers/Content-Security-Policy/referrer...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTTP/Headers/Content-Security-Policy/report-to...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTTP/Headers/Content-Security-Policy/report-uri...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTTP/Headers/Content-Security-Policy/require-trusted-types-for...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTTP/Headers/Content-Security-Policy/sandbox...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTTP/Headers/Content-Security-Policy/script-src...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTTP/Headers/Content-Security-Policy/script-src-attr...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTTP/Headers/Content-Security-Policy/script-src-elem...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTTP/Headers/Content-Security-Policy/style-src...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTTP/Headers/Content-Security-Policy/style-src-attr...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTTP/Headers/Content-Security-Policy/style-src-elem...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTTP/Headers/Content-Security-Policy/trusted-types...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTTP/Headers/Content-Security-Policy/upgrade-insecure-requests...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTTP/Headers/Content-Security-Policy/worker-src...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTTP/CORS/Errors/CORSDisabled...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTTP/CORS/Errors/CORSAllowOriginNotMatchingOrigin...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTTP/CORS/Errors/CORSMissingAllowOrigin...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTTP/CORS/Errors/CORSOriginHeaderNotAdded...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTTP/CORS/Errors/CORSPreflightDidNotSucceed...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTTP/CORS/Errors/CORSDidNotSucceed...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTTP/CORS/Errors/CORSExternalRedirectNotAllowed...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTTP/CORS/Errors/CORSRequestNotHttp...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTTP/CORS/Errors/CORSNotSupportingCredentials...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTTP/CORS/Errors/CORSMethodNotFound...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTTP/CORS/Errors/CORSMIssingAllowCredentials...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTTP/CORS/Errors/CORSInvalidAllowHeader...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTTP/CORS/Errors/CORSInvalidAllowMethod...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTTP/CORS/Errors/CORSMissingAllowHeaderFromPreflight...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTTP/CORS/Errors/CORSMultipleAllowOriginNotAllowed...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTTP/Headers/Permissions-Policy/accelerometer...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTTP/Headers/Permissions-Policy/ambient-light-sensor...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTTP/Headers/Permissions-Policy/autoplay...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTTP/Headers/Permissions-Policy/battery...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTTP/Headers/Permissions-Policy/camera...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTTP/Headers/Permissions-Policy/display-capture...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTTP/Headers/Permissions-Policy/document-domain...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTTP/Headers/Permissions-Policy/encrypted-media...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTTP/Headers/Permissions-Policy/execution-while-not-rendered...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTTP/Headers/Permissions-Policy/execution-while-out-of-viewport...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTTP/Headers/Permissions-Policy/fullscreen...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTTP/Headers/Permissions-Policy/gamepad...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTTP/Headers/Permissions-Policy/geolocation...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTTP/Headers/Permissions-Policy/gyroscope...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTTP/Headers/Permissions-Policy/hid...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTTP/Headers/Permissions-Policy/identity-credentials-get...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTTP/Headers/Permissions-Policy/idle-detection...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTTP/Headers/Permissions-Policy/local-fonts...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTTP/Headers/Permissions-Policy/magnetometer...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTTP/Headers/Permissions-Policy/microphone...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTTP/Headers/Permissions-Policy/midi...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTTP/Headers/Permissions-Policy/otp-credentials...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTTP/Headers/Permissions-Policy/payment...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTTP/Headers/Permissions-Policy/picture-in-picture...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTTP/Headers/Permissions-Policy/publickey-credentials-create...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTTP/Headers/Permissions-Policy/publickey-credentials-get...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTTP/Headers/Permissions-Policy/screen-wake-lock...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTTP/Headers/Permissions-Policy/serial...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTTP/Headers/Permissions-Policy/speaker-selection...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTTP/Headers/Permissions-Policy/storage-access...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTTP/Headers/Permissions-Policy/usb...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTTP/Headers/Permissions-Policy/web-share...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTTP/Headers/Permissions-Policy/window-management...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTTP/Headers/Permissions-Policy/xr-spatial-tracking...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTTP/Client_hints...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTTP/Headers...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTTP/Methods...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTTP/Status...
# Scraping https://developer.mozilla.org/en-US/docs/Web/HTTP/contributors.txt...
# Scraping https://developer.mozilla.org/en-US/docs/Web/API#content...
# Scraping https://developer.mozilla.org/en-US/docs/Web/API#top-nav-search-input...
# Scraping https://developer.mozilla.org/en-US/docs/Web/API#languages-switcher-button...
# Scraping https://developer.mozilla.org/users/fxa/login/authenticate/?next=%2Fen-US%2Fdocs%2FWeb%2FAPI...
# Scraping https://developer.mozilla.org/en-US/docs/Web/API#specifications...
# Scraping https://developer.mozilla.org/en-US/docs/Web/API#interfaces...
# Scraping https://developer.mozilla.org/en-US/docs/Web/API#see_also...
# Scraping https://developer.mozilla.org/en-US/docs/Web/API/Audio_Output_Devices_API...
# Scraping https://developer.mozilla.org/en-US/docs/Web/API/Background_Fetch_API...
# Scraping https://developer.mozilla.org/en-US/docs/Web/API/Background_Synchronization_API...
# Scraping https://developer.mozilla.org/en-US/docs/Web/API/Background_Tasks_API...
# Scraping https://developer.mozilla.org/en-US/docs/Web/API/Badging_API...
# Scraping https://developer.mozilla.org/en-US/docs/Web/API/Barcode_Detection_API...
# Scraping https://developer.mozilla.org/en-US/docs/Web/API/Battery_Status_API...
# Scraping https://developer.mozilla.org/en-US/docs/Web/API/Beacon_API...
# Scraping https://developer.mozilla.org/en-US/docs/Web/API/Web_Bluetooth_API...
# Scraping https://developer.mozilla.org/en-US/docs/Web/API/Broadcast_Channel_API...
# Scraping https://developer.mozilla.org/en-US/docs/Web/API/CSS_Counter_Styles...
# Scraping https://developer.mozilla.org/en-US/docs/Web/API/CSS_Custom_Highlight_API...
# Scraping https://developer.mozilla.org/en-US/docs/Web/API/CSS_Font_Loading_API...
# Scraping https://developer.mozilla.org/en-US/docs/Web/API/CSS_Painting_API...
# Scraping https://developer.mozilla.org/en-US/docs/Web/API/CSS_Properties_and_Values_API...
# Scraping https://developer.mozilla.org/en-US/docs/Web/API/CSS_Typed_OM_API...
# Scraping https://developer.mozilla.org/en-US/docs/Web/API/CSS_Object_Model...
# Scraping https://developer.mozilla.org/en-US/docs/Web/API/Canvas_API...
# Scraping https://developer.mozilla.org/en-US/docs/Web/API/Channel_Messaging_API...
# Scraping https://developer.mozilla.org/en-US/docs/Web/API/Clipboard_API...
# Scraping https://developer.mozilla.org/en-US/docs/Web/API/Compression_Streams_API...
# Scraping https://developer.mozilla.org/en-US/docs/Web/API/Console_API...
# Scraping https://developer.mozilla.org/en-US/docs/Web/API/Contact_Picker_API...
# Scraping https://developer.mozilla.org/en-US/docs/Web/API/Content_Index_API...
# Scraping https://developer.mozilla.org/en-US/docs/Web/API/Cookie_Store_API...
# Scraping https://developer.mozilla.org/en-US/docs/Web/API/Credential_Management_API...
# Scraping https://developer.mozilla.org/en-US/docs/Web/API/Document_Object_Model...
# Scraping https://developer.mozilla.org/en-US/docs/Web/API/Device_Memory_API...
# Scraping https://developer.mozilla.org/en-US/docs/Web/API/Device_orientation_events...
# Scraping https://developer.mozilla.org/en-US/docs/Web/API/Document_Picture-in-Picture_API...
# Scraping https://developer.mozilla.org/en-US/docs/Web/API/EditContext_API...
# Scraping https://developer.mozilla.org/en-US/docs/Web/API/Encoding_API...
# Scraping https://developer.mozilla.org/en-US/docs/Web/API/Encrypted_Media_Extensions_API...
# Scraping https://developer.mozilla.org/en-US/docs/Web/API/EyeDropper_API...
# Scraping https://developer.mozilla.org/en-US/docs/Web/API/FedCM_API...
# Scraping https://developer.mozilla.org/en-US/docs/Web/API/Fetch_API...
# Scraping https://developer.mozilla.org/en-US/docs/Web/API/File_API...
# Scraping https://developer.mozilla.org/en-US/docs/Web/API/File_System_API...
# Scraping https://developer.mozilla.org/en-US/docs/Web/API/File_and_Directory_Entries_API...
# Scraping https://developer.mozilla.org/en-US/docs/Web/API/Force_Touch_events...
# Scraping https://developer.mozilla.org/en-US/docs/Web/API/Fullscreen_API...
# Scraping https://developer.mozilla.org/en-US/docs/Web/API/Gamepad_API...
# Scraping https://developer.mozilla.org/en-US/docs/Web/API/Geolocation_API...
# Scraping https://developer.mozilla.org/en-US/docs/Web/API/Geometry_interfaces...
# Scraping https://developer.mozilla.org/en-US/docs/Web/API/HTML_DOM_API...
# Scraping https://developer.mozilla.org/en-US/docs/Web/API/HTML_Drag_and_Drop_API...
# Scraping https://developer.mozilla.org/en-US/docs/Web/API/HTML_Sanitizer_API...
# Scraping https://developer.mozilla.org/en-US/docs/Web/API/History_API...
# Scraping https://developer.mozilla.org/en-US/docs/Web/API/Houdini_APIs...
# Scraping https://developer.mozilla.org/en-US/docs/Web/API/Idle_Detection_API...
# Scraping https://developer.mozilla.org/en-US/docs/Web/API/MediaStream_Image_Capture_API...
# Scraping https://developer.mozilla.org/en-US/docs/Web/API/IndexedDB_API...
# Scraping https://developer.mozilla.org/en-US/docs/Web/API/Ink_API...
# Scraping https://developer.mozilla.org/en-US/docs/Web/API/InputDeviceCapabilities_API...
# Scraping https://developer.mozilla.org/en-US/docs/Web/API/Insertable_Streams_for_MediaStreamTrack_API...
# Scraping https://developer.mozilla.org/en-US/docs/Web/API/Intersection_Observer_API...
# Scraping https://developer.mozilla.org/en-US/docs/Web/API/Keyboard_API...
# Scraping https://developer.mozilla.org/en-US/docs/Web/API/Launch_Handler_API...
# Scraping https://developer.mozilla.org/en-US/docs/Web/API/Local_Font_Access_API...
# Scraping https://developer.mozilla.org/en-US/docs/Web/API/Media_Capabilities_API...
# Scraping https://developer.mozilla.org/en-US/docs/Web/API/Media_Capture_and_Streams_API...
# Scraping https://developer.mozilla.org/en-US/docs/Web/API/Media_Session_API...
# Scraping https://developer.mozilla.org/en-US/docs/Web/API/Media_Source_Extensions_API...
# Scraping https://developer.mozilla.org/en-US/docs/Web/API/MediaStream_Recording_API...
# Scraping https://developer.mozilla.org/en-US/docs/Web/API/Navigation_API...
# Scraping https://developer.mozilla.org/en-US/docs/Web/API/Network_Information_API...
# Scraping https://developer.mozilla.org/en-US/docs/Web/API/Page_Visibility_API...
# Scraping https://developer.mozilla.org/en-US/docs/Web/API/Payment_Handler_API...
# Scraping https://developer.mozilla.org/en-US/docs/Web/API/Payment_Request_API...

# %%
# Function to save scraped data to a file
def print_retrieved_data(data):
    i = 0
    for page_data in data:
        if i < 5:
          print(f"URL: {page_data['url']}")
          print("Paragraphs:")
          for paragraph in page_data['paragraphs']:
              print(paragraph)
          print("-" * 80)
          print()  # Add a newline after each page_data
          i += 1
        else:
          break

print_retrieved_data(scraped_data)
# Out:
# URL:  https://developer.mozilla.org/en-US/docs/Web/JavaScript
# Paragraphs:
# JavaScript (JS) is a lightweight interpreted (or just-in-time compiled) programming language with first-class functions. While it is most well-known as the scripting language for Web pages, many non-browser environments also use it, such as Node.js, Apache CouchDB and Adobe Acrobat. JavaScript is a prototype-based, multi-paradigm, single-threaded, dynamic language, supporting object-oriented, imperative, and declarative (e.g. functional programming) styles.
# JavaScript's dynamic capabilities include runtime object construction, variable parameter lists, function variables, dynamic script creation (via eval), object introspection (via for...in and Object utilities), and source-code recovery (JavaScript functions store their source text and can be retrieved through toString()).
# This section is dedicated to the JavaScript language itself, and not the parts that are specific to Web pages or other host environments. For information about APIs that are specific to Web pages, please see Web APIs and DOM.
# The standards for JavaScript are the ECMAScript Language Specification (ECMA-262) and the ECMAScript Internationalization API specification (ECMA-402). As soon as one browser implements a feature, we try to document it. This means that cases where some proposals for new ECMAScript features have already been implemented in browsers, documentation and examples in MDN articles may use some of those new features. Most of the time, this happens between the stages 3 and 4, and is usually before the spec is officially published.
# Do not confuse JavaScript with the Java programming language â JavaScript is not "Interpreted Java". Both "Java" and "JavaScript" are trademarks or registered trademarks of Oracle in the U.S. and other countries. However, the two programming languages have very different syntax, semantics, and use.
# JavaScript documentation of core language features (pure ECMAScript, for the most part) includes the following:
# For more information about JavaScript specifications and related technologies, see JavaScript technologies overview.
# Looking to become a front-end web developer?
# We have put together a course that includes all the essential information you need to
#     work towards your goal.
# Get started
# Learn how to program in JavaScript with guides and tutorials.
# Head over to our Learning Area JavaScript topic if you want to learn JavaScript but have no previous experience with JavaScript or programming. The complete modules available there are as follows:
# Answers some fundamental questions such as "what is JavaScript?", "what does it look like?", and "what can it do?", along with discussing key JavaScript features such as variables, strings, numbers, and arrays.
# Continues our coverage of JavaScript's key fundamental features, turning our attention to commonly-encountered types of code blocks such as conditional statements, loops, functions, and events.
# The object-oriented nature of JavaScript is important to understand if you want to go further with your knowledge of the language and write more efficient code, therefore we've provided this module to help you.
# Discusses asynchronous JavaScript, why it is important, and how it can be used to effectively handle potential blocking operations such as fetching resources from a server.
# Explores what APIs are, and how to use some of the most common APIs you'll come across often in your development work.
# A much more detailed guide to the JavaScript language, aimed at those with previous programming experience either in JavaScript or another language.
# JavaScript frameworks are an essential part of modern front-end web development, providing developers with proven tools for building scalable, interactive web applications. This module gives you some fundamental background knowledge about how client-side frameworks work and how they fit into your toolset, before moving on to a series of tutorials covering some of today's most popular ones.
# An overview of the basic syntax and semantics of JavaScript for those coming from other programming languages to get up to speed.
# Overview of available data structures in JavaScript.
# JavaScript provides three different value comparison operations: strict equality using ===, loose equality using ==, and the Object.is() method.
# How different methods that visit a group of object properties one-by-one handle the enumerability and ownership of properties.
# A closure is the combination of a function and the lexical environment within which that function was declared.
# Explanation of the widely misunderstood and underestimated prototype-based inheritance.
# Memory life cycle and garbage collection in JavaScript.
# JavaScript has a runtime model based on an "event loop".
# Browse the complete JavaScript reference documentation.
# Get to know standard built-in objects Array, Boolean, Date, Error, Function, JSON, Math, Number, Object, RegExp, String, Map, Set, WeakMap, WeakSet, and others.
# Learn more about the behavior of JavaScript's operators instanceof, typeof, new, this, the operator precedence, and more.
# Learn how do-while, for-in, for-of, try-catch, let, var, const, if-else, switch, and more JavaScript statements and keywords work.
# Learn how to work with JavaScript's functions to develop your applications.
# JavaScript classes are the most appropriate way to do object-oriented programming.
# This page was last modified on Sep 25, 2023 by MDN contributors.
# --------------------------------------------------------------------------------
#
# URL: https://developer.mozilla.org/en-US/docs/Web/JavaScript#content
# Paragraphs:
# JavaScript (JS) is a lightweight interpreted (or just-in-time compiled) programming language with first-class functions. While it is most well-known as the scripting language for Web pages, many non-browser environments also use it, such as Node.js, Apache CouchDB and Adobe Acrobat. JavaScript is a prototype-based, multi-paradigm, single-threaded, dynamic language, supporting object-oriented, imperative, and declarative (e.g. functional programming) styles.
# JavaScript's dynamic capabilities include runtime object construction, variable parameter lists, function variables, dynamic script creation (via eval), object introspection (via for...in and Object utilities), and source-code recovery (JavaScript functions store their source text and can be retrieved through toString()).
# This section is dedicated to the JavaScript language itself, and not the parts that are specific to Web pages or other host environments. For information about APIs that are specific to Web pages, please see Web APIs and DOM.
# The standards for JavaScript are the ECMAScript Language Specification (ECMA-262) and the ECMAScript Internationalization API specification (ECMA-402). As soon as one browser implements a feature, we try to document it. This means that cases where some proposals for new ECMAScript features have already been implemented in browsers, documentation and examples in MDN articles may use some of those new features. Most of the time, this happens between the stages 3 and 4, and is usually before the spec is officially published.
# Do not confuse JavaScript with the Java programming language â JavaScript is not "Interpreted Java". Both "Java" and "JavaScript" are trademarks or registered trademarks of Oracle in the U.S. and other countries. However, the two programming languages have very different syntax, semantics, and use.
# JavaScript documentation of core language features (pure ECMAScript, for the most part) includes the following:
# For more information about JavaScript specifications and related technologies, see JavaScript technologies overview.
# Looking to become a front-end web developer?
# We have put together a course that includes all the essential information you need to
#     work towards your goal.
# Get started
# Learn how to program in JavaScript with guides and tutorials.
# Head over to our Learning Area JavaScript topic if you want to learn JavaScript but have no previous experience with JavaScript or programming. The complete modules available there are as follows:
# Answers some fundamental questions such as "what is JavaScript?", "what does it look like?", and "what can it do?", along with discussing key JavaScript features such as variables, strings, numbers, and arrays.
# Continues our coverage of JavaScript's key fundamental features, turning our attention to commonly-encountered types of code blocks such as conditional statements, loops, functions, and events.
# The object-oriented nature of JavaScript is important to understand if you want to go further with your knowledge of the language and write more efficient code, therefore we've provided this module to help you.
# Discusses asynchronous JavaScript, why it is important, and how it can be used to effectively handle potential blocking operations such as fetching resources from a server.
# Explores what APIs are, and how to use some of the most common APIs you'll come across often in your development work.
# A much more detailed guide to the JavaScript language, aimed at those with previous programming experience either in JavaScript or another language.
# JavaScript frameworks are an essential part of modern front-end web development, providing developers with proven tools for building scalable, interactive web applications. This module gives you some fundamental background knowledge about how client-side frameworks work and how they fit into your toolset, before moving on to a series of tutorials covering some of today's most popular ones.
# An overview of the basic syntax and semantics of JavaScript for those coming from other programming languages to get up to speed.
# Overview of available data structures in JavaScript.
# JavaScript provides three different value comparison operations: strict equality using ===, loose equality using ==, and the Object.is() method.
# How different methods that visit a group of object properties one-by-one handle the enumerability and ownership of properties.
# A closure is the combination of a function and the lexical environment within which that function was declared.
# Explanation of the widely misunderstood and underestimated prototype-based inheritance.
# Memory life cycle and garbage collection in JavaScript.
# JavaScript has a runtime model based on an "event loop".
# Browse the complete JavaScript reference documentation.
# Get to know standard built-in objects Array, Boolean, Date, Error, Function, JSON, Math, Number, Object, RegExp, String, Map, Set, WeakMap, WeakSet, and others.
# Learn more about the behavior of JavaScript's operators instanceof, typeof, new, this, the operator precedence, and more.
# Learn how do-while, for-in, for-of, try-catch, let, var, const, if-else, switch, and more JavaScript statements and keywords work.
# Learn how to work with JavaScript's functions to develop your applications.
# JavaScript classes are the most appropriate way to do object-oriented programming.
# This page was last modified on Sep 25, 2023 by MDN contributors.
# --------------------------------------------------------------------------------
#
# URL: https://developer.mozilla.org/en-US/docs/Web/JavaScript#top-nav-search-input
# Paragraphs:
# JavaScript (JS) is a lightweight interpreted (or just-in-time compiled) programming language with first-class functions. While it is most well-known as the scripting language for Web pages, many non-browser environments also use it, such as Node.js, Apache CouchDB and Adobe Acrobat. JavaScript is a prototype-based, multi-paradigm, single-threaded, dynamic language, supporting object-oriented, imperative, and declarative (e.g. functional programming) styles.
# JavaScript's dynamic capabilities include runtime object construction, variable parameter lists, function variables, dynamic script creation (via eval), object introspection (via for...in and Object utilities), and source-code recovery (JavaScript functions store their source text and can be retrieved through toString()).
# This section is dedicated to the JavaScript language itself, and not the parts that are specific to Web pages or other host environments. For information about APIs that are specific to Web pages, please see Web APIs and DOM.
# The standards for JavaScript are the ECMAScript Language Specification (ECMA-262) and the ECMAScript Internationalization API specification (ECMA-402). As soon as one browser implements a feature, we try to document it. This means that cases where some proposals for new ECMAScript features have already been implemented in browsers, documentation and examples in MDN articles may use some of those new features. Most of the time, this happens between the stages 3 and 4, and is usually before the spec is officially published.
# Do not confuse JavaScript with the Java programming language â JavaScript is not "Interpreted Java". Both "Java" and "JavaScript" are trademarks or registered trademarks of Oracle in the U.S. and other countries. However, the two programming languages have very different syntax, semantics, and use.
# JavaScript documentation of core language features (pure ECMAScript, for the most part) includes the following:
# For more information about JavaScript specifications and related technologies, see JavaScript technologies overview.
# Looking to become a front-end web developer?
# We have put together a course that includes all the essential information you need to
#     work towards your goal.
# Get started
# Learn how to program in JavaScript with guides and tutorials.
# Head over to our Learning Area JavaScript topic if you want to learn JavaScript but have no previous experience with JavaScript or programming. The complete modules available there are as follows:
# Answers some fundamental questions such as "what is JavaScript?", "what does it look like?", and "what can it do?", along with discussing key JavaScript features such as variables, strings, numbers, and arrays.
# Continues our coverage of JavaScript's key fundamental features, turning our attention to commonly-encountered types of code blocks such as conditional statements, loops, functions, and events.
# The object-oriented nature of JavaScript is important to understand if you want to go further with your knowledge of the language and write more efficient code, therefore we've provided this module to help you.
# Discusses asynchronous JavaScript, why it is important, and how it can be used to effectively handle potential blocking operations such as fetching resources from a server.
# Explores what APIs are, and how to use some of the most common APIs you'll come across often in your development work.
# A much more detailed guide to the JavaScript language, aimed at those with previous programming experience either in JavaScript or another language.
# JavaScript frameworks are an essential part of modern front-end web development, providing developers with proven tools for building scalable, interactive web applications. This module gives you some fundamental background knowledge about how client-side frameworks work and how they fit into your toolset, before moving on to a series of tutorials covering some of today's most popular ones.
# An overview of the basic syntax and semantics of JavaScript for those coming from other programming languages to get up to speed.
# Overview of available data structures in JavaScript.
# JavaScript provides three different value comparison operations: strict equality using ===, loose equality using ==, and the Object.is() method.
# How different methods that visit a group of object properties one-by-one handle the enumerability and ownership of properties.
# A closure is the combination of a function and the lexical environment within which that function was declared.
# Explanation of the widely misunderstood and underestimated prototype-based inheritance.
# Memory life cycle and garbage collection in JavaScript.
# JavaScript has a runtime model based on an "event loop".
# Browse the complete JavaScript reference documentation.
# Get to know standard built-in objects Array, Boolean, Date, Error, Function, JSON, Math, Number, Object, RegExp, String, Map, Set, WeakMap, WeakSet, and others.
# Learn more about the behavior of JavaScript's operators instanceof, typeof, new, this, the operator precedence, and more.
# Learn how do-while, for-in, for-of, try-catch, let, var, const, if-else, switch, and more JavaScript statements and keywords work.
# Learn how to work with JavaScript's functions to develop your applications.
# JavaScript classes are the most appropriate way to do object-oriented programming.
# This page was last modified on Sep 25, 2023 by MDN contributors.
# --------------------------------------------------------------------------------
#
# URL: https://developer.mozilla.org/en-US/docs/Web/JavaScript#languages-switcher-button
# Paragraphs:
# JavaScript (JS) is a lightweight interpreted (or just-in-time compiled) programming language with first-class functions. While it is most well-known as the scripting language for Web pages, many non-browser environments also use it, such as Node.js, Apache CouchDB and Adobe Acrobat. JavaScript is a prototype-based, multi-paradigm, single-threaded, dynamic language, supporting object-oriented, imperative, and declarative (e.g. functional programming) styles.
# JavaScript's dynamic capabilities include runtime object construction, variable parameter lists, function variables, dynamic script creation (via eval), object introspection (via for...in and Object utilities), and source-code recovery (JavaScript functions store their source text and can be retrieved through toString()).
# This section is dedicated to the JavaScript language itself, and not the parts that are specific to Web pages or other host environments. For information about APIs that are specific to Web pages, please see Web APIs and DOM.
# The standards for JavaScript are the ECMAScript Language Specification (ECMA-262) and the ECMAScript Internationalization API specification (ECMA-402). As soon as one browser implements a feature, we try to document it. This means that cases where some proposals for new ECMAScript features have already been implemented in browsers, documentation and examples in MDN articles may use some of those new features. Most of the time, this happens between the stages 3 and 4, and is usually before the spec is officially published.
# Do not confuse JavaScript with the Java programming language â JavaScript is not "Interpreted Java". Both "Java" and "JavaScript" are trademarks or registered trademarks of Oracle in the U.S. and other countries. However, the two programming languages have very different syntax, semantics, and use.
# JavaScript documentation of core language features (pure ECMAScript, for the most part) includes the following:
# For more information about JavaScript specifications and related technologies, see JavaScript technologies overview.
# Looking to become a front-end web developer?
# We have put together a course that includes all the essential information you need to
#     work towards your goal.
# Get started
# Learn how to program in JavaScript with guides and tutorials.
# Head over to our Learning Area JavaScript topic if you want to learn JavaScript but have no previous experience with JavaScript or programming. The complete modules available there are as follows:
# Answers some fundamental questions such as "what is JavaScript?", "what does it look like?", and "what can it do?", along with discussing key JavaScript features such as variables, strings, numbers, and arrays.
# Continues our coverage of JavaScript's key fundamental features, turning our attention to commonly-encountered types of code blocks such as conditional statements, loops, functions, and events.
# The object-oriented nature of JavaScript is important to understand if you want to go further with your knowledge of the language and write more efficient code, therefore we've provided this module to help you.
# Discusses asynchronous JavaScript, why it is important, and how it can be used to effectively handle potential blocking operations such as fetching resources from a server.
# Explores what APIs are, and how to use some of the most common APIs you'll come across often in your development work.
# A much more detailed guide to the JavaScript language, aimed at those with previous programming experience either in JavaScript or another language.
# JavaScript frameworks are an essential part of modern front-end web development, providing developers with proven tools for building scalable, interactive web applications. This module gives you some fundamental background knowledge about how client-side frameworks work and how they fit into your toolset, before moving on to a series of tutorials covering some of today's most popular ones.
# An overview of the basic syntax and semantics of JavaScript for those coming from other programming languages to get up to speed.
# Overview of available data structures in JavaScript.
# JavaScript provides three different value comparison operations: strict equality using ===, loose equality using ==, and the Object.is() method.
# How different methods that visit a group of object properties one-by-one handle the enumerability and ownership of properties.
# A closure is the combination of a function and the lexical environment within which that function was declared.
# Explanation of the widely misunderstood and underestimated prototype-based inheritance.
# Memory life cycle and garbage collection in JavaScript.
# JavaScript has a runtime model based on an "event loop".
# Browse the complete JavaScript reference documentation.
# Get to know standard built-in objects Array, Boolean, Date, Error, Function, JSON, Math, Number, Object, RegExp, String, Map, Set, WeakMap, WeakSet, and others.
# Learn more about the behavior of JavaScript's operators instanceof, typeof, new, this, the operator precedence, and more.
# Learn how do-while, for-in, for-of, try-catch, let, var, const, if-else, switch, and more JavaScript statements and keywords work.
# Learn how to work with JavaScript's functions to develop your applications.
# JavaScript classes are the most appropriate way to do object-oriented programming.
# This page was last modified on Sep 25, 2023 by MDN contributors.
# --------------------------------------------------------------------------------
#
# URL: https://developer.mozilla.org/en-US/
# Paragraphs:
# --------------------------------------------------------------------------------

# %%
print(len(scraped_data))
# Out:
# 2000

# %%
import re

def clean_text(text):
    cleaned_text = re.sub(r'[^a-zA-Z\s]', '', text)  # Example: Remove non-alphabetic characters
    cleaned_text = cleaned_text.lower()  # Example: Convert to lowercase
    return cleaned_text

# Clean the text
new_scraped_data = {}
i = 0
for data in scraped_data:
  for line in data['paragraphs']:
    new_scraped_data[i] = clean_text(line)
    i+=1

# %%
for j in range(10):
  print(new_scraped_data[j])
# Out:
# javascript js is a lightweight interpreted or justintime compiled programming language with firstclass functions while it is most wellknown as the scripting language for web pages many nonbrowser environments also use it such as nodejs apache couchdb and adobe acrobat javascript is a prototypebased multiparadigm singlethreaded dynamic language supporting objectoriented imperative and declarative eg functional programming styles
# javascripts dynamic capabilities include runtime object construction variable parameter lists function variables dynamic script creation via eval object introspection via forin and object utilities and sourcecode recovery javascript functions store their source text and can be retrieved through tostring
# this section is dedicated to the javascript language itself and not the parts that are specific to web pages or other host environments for information about apis that are specific to web pages please see web apis and dom
# the standards for javascript are the ecmascript language specification ecma and the ecmascript internationalization api specification ecma as soon as one browser implements a feature we try to document it this means that cases where some proposals for new ecmascript features have already been implemented in browsers documentation and examples in mdn articles may use some of those new features most of the time this happens between the stages  and  and is usually before the spec is officially published
# do not confuse javascript with the java programming language  javascript is not interpreted java both java and javascript are trademarks or registered trademarks of oracle in the us and other countries however the two programming languages have very different syntax semantics and use
# javascript documentation of core language features pure ecmascript for the most part includes the following
# for more information about javascript specifications and related technologies see javascript technologies overview
# looking to become a frontend web developer
# we have put together a course that includes all the essential information you need to
#     work towards your goal
# get started

# %%
with open('js_docs_text_data.txt', 'w') as dump:
  for j in range(i):
    print(new_scraped_data[j], file=dump)

# %%
print(i)
# Out:
# 32641
